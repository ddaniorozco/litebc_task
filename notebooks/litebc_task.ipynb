# %%
# !git clone https://github.com/ultralytics/ultralytics.git

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from ultralytics import YOLO

# %%
# Train model

# !yolo task=detect mode=train model=/content/capillary/random_yolo.pt data=/content/capillary/capillary.yaml imgsz=320 epochs=100 batch=16 dropout=0.3
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load a model
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/capillary/split/validation.cache... 109 images, 3 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:20<00:00,  2.93s/it]
#                    all        112       3357      0.648      0.466      0.529      0.216
#                 BLURRY        112       1989      0.616      0.334      0.434      0.165
#                SHARP_0        112       1041      0.674      0.622       0.68      0.289
#                 BUBBLE        112        327      0.656       0.44      0.473      0.192
# Speed: 1.3ms preprocess, 7.8ms inference, 0.0ms loss, 18.5ms postprocess per image
# Results saved to runs/detect/val
# array([    0.16538,     0.28931,     0.19236])

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model.predict(source='/content/capillary/split/images_validation', save=True, save_txt=True)
# Out:
# image 1/112 /content/capillary/split/images_validation/33355.png: 288x320 7 BLURRYs, 30 SHARP_0s, 102.6ms
# image 2/112 /content/capillary/split/images_validation/33358.png: 288x320 14 BLURRYs, 8.3ms
# image 3/112 /content/capillary/split/images_validation/33359.png: 288x320 26 BLURRYs, 2 SHARP_0s, 10.6ms
# image 4/112 /content/capillary/split/images_validation/33366.png: 288x320 7 BLURRYs, 1 BUBBLE, 12.1ms
# image 5/112 /content/capillary/split/images_validation/33381.png: 288x320 4 BLURRYs, 19 SHARP_0s, 8.3ms
# image 6/112 /content/capillary/split/images_validation/33384.png: 288x320 8 BLURRYs, 18 SHARP_0s, 8.1ms
# image 7/112 /content/capillary/split/images_validation/33408.png: 288x320 11 BLURRYs, 4 SHARP_0s, 8.4ms
# image 8/112 /content/capillary/split/images_validation/33411.png: 288x320 3 BLURRYs, 28 SHARP_0s, 8.3ms
# image 9/112 /content/capillary/split/images_validation/33425.png: 288x320 5 BLURRYs, 1 BUBBLE, 9.3ms
# ...
